# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#importing datasets 
df= pd.read_excel("/content/drive/MyDrive/Vaccine-history-dataset/new-dataset.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   SYMPTOM1      890836 non-null   object
#  1   SYMPTOM2      700014 non-null   object
#  2   SYMPTOM3      542889 non-null   object
#  3   SYMPTOM4      414887 non-null   object
#  4   SYMPTOM5      311516 non-null   object
#  5   BinarySym1    1048575 non-null  int64
#  6   BinarySym2    1048575 non-null  int64
#  7   BinarySym3    1048575 non-null  int64
#  8   BinarySym4    1048575 non-null  int64
#  9   BinarySym5    1048575 non-null  int64
#  10  Total         1048575 non-null  int64
#  11  VAX_MANU      890836 non-null   object
#  12  AGE_YRS       819268 non-null   float64
#  13  SEX           890836 non-null   object
#  14  SYMPTOM_TEXT  890447 non-null   object
#  15  RECOVD        817819 non-null   object
#  16  HISTORY       594550 non-null   object
# ...

# %%
df.head()
# Out:
#                   SYMPTOM1  ...                                            HISTORY
# 0                Dysphagia  ...                                               None
# 1                  Anxiety  ...  Patient residing at nursing facility. See pati...
# 2         Chest discomfort  ...                                               None
# 3                Dizziness  ...  diverticulitis, mitral valve prolapse, osteoar...
# 4  Injection site erythema  ...                                                NaN
#
# [5 rows x 17 columns]

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total VAX_MANU  AGE_YRS SEX HISTORY
# 208         4  MODERNA     30.0   F  Asthma
# 919         5  MODERNA     21.0   F  Asthma
# 1009        5  MODERNA     23.0   F  Asthma
# 1021        1  MODERNA     27.0   F  Asthma
# 1044        5  MODERNA     23.0   F  Asthma
# ...       ...      ...      ...  ..     ...
# 886489      5  MODERNA     25.0   F  Asthma
# 886490      3  MODERNA     25.0   F  Asthma
# 888608      2  MODERNA     27.0   F  Asthma
# 889297      5  MODERNA     28.0   F  Asthma
# 889298      4  MODERNA     28.0   F  Asthma
#
# [676 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

from collections import Counter

# %%
print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 281, 4: 120, 2: 99, 3: 93, 1: 83})
# Counter({1: 83, 2: 99, 3: 93, 4: 120, 5: 281})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

# %%
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 21-30)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 375, 3: 129, 1: 121, 2: 118, 4: 103})
# Counter({1: 121, 2: 118, 3: 129, 4: 103, 5: 375})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

# %%
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 288, 2: 110, 3: 108, 1: 100, 4: 92})
# Counter({1: 100, 2: 110, 3: 108, 4: 92, 5: 288})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 202, 2: 83, 3: 80, 1: 73, 4: 65})
# Counter({1: 73, 2: 83, 3: 80, 4: 65, 5: 202})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 108, 3: 49, 4: 49, 2: 44, 1: 37})
# Counter({1: 37, 2: 44, 3: 49, 4: 49, 5: 108})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 29, 4: 17, 2: 17, 3: 11, 1: 11})
# Counter({1: 11, 2: 17, 3: 11, 4: 17, 5: 29})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 71-80)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=81) &(df['AGE_YRS']<=90)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({3: 5, 5: 5, 2: 2, 1: 2, 4: 2})
# Counter({1: 2, 2: 2, 3: 5, 4: 2, 5: 5})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Female (Age 81-90)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 196, 3: 93, 1: 90, 2: 78, 4: 63})
# Counter({1: 90, 2: 78, 3: 93, 4: 63, 5: 196})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 21-30)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 308, 2: 118, 4: 109, 3: 108, 1: 100})
# Counter({1: 100, 2: 118, 3: 108, 4: 109, 5: 308})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 234, 2: 98, 1: 92, 3: 85, 4: 69})
# Counter({1: 92, 2: 98, 3: 85, 4: 69, 5: 234})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 140, 2: 61, 3: 60, 1: 55, 4: 41})
# Counter({1: 55, 2: 61, 3: 60, 4: 41, 5: 140})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 78, 1: 37, 2: 34, 3: 32, 4: 23})
# Counter({1: 37, 2: 34, 3: 32, 4: 23, 5: 78})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 23, 1: 10, 3: 9, 2: 8, 4: 8})
# Counter({1: 10, 2: 8, 3: 9, 4: 8, 5: 23})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 71-80)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=81) &(df['AGE_YRS']<=90)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 3, 1: 2, 2: 1, 4: 1, 3: 1})
# Counter({1: 2, 2: 1, 3: 1, 4: 1, 5: 3})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 81-90)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=91) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({2: 1})
# Counter({2: 1})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Female (Age 91-100)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 59, 3: 21, 1: 19, 4: 18, 2: 15})
# Counter({1: 19, 2: 15, 3: 21, 4: 18, 5: 59})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 21-30)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 71, 3: 27, 2: 25, 4: 19, 1: 18})
# Counter({1: 18, 2: 25, 3: 27, 4: 19, 5: 71})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 91, 1: 25, 3: 21, 2: 15, 4: 15})
# Counter({1: 25, 2: 15, 3: 21, 4: 15, 5: 91})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 39, 3: 14, 4: 14, 1: 14, 2: 9})
# Counter({1: 14, 2: 9, 3: 14, 4: 14, 5: 39})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 23, 4: 8, 3: 6, 2: 6, 1: 4})
# Counter({1: 4, 2: 6, 3: 6, 4: 8, 5: 23})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({2: 2, 4: 2, 1: 1})
# Counter({1: 1, 2: 2, 4: 2})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Female (Age 71-80)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 52, 1: 30, 3: 28, 2: 23, 4: 15})
# Counter({1: 30, 2: 23, 3: 28, 4: 15, 5: 52})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 21-30)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 62, 2: 32, 1: 27, 4: 24, 3: 20})
# Counter({1: 27, 2: 32, 3: 20, 4: 24, 5: 62})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 46, 1: 18, 3: 16, 2: 11, 4: 11})
# Counter({1: 18, 2: 11, 3: 16, 4: 11, 5: 46})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 31, 3: 12, 1: 12, 2: 11, 4: 8})
# Counter({1: 12, 2: 11, 3: 12, 4: 8, 5: 31})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 14, 1: 13, 4: 10, 3: 7, 2: 6})
# Counter({1: 13, 2: 6, 3: 7, 4: 10, 5: 14})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 10, 3: 5, 2: 3, 4: 3, 1: 1})
# Counter({1: 1, 2: 3, 3: 5, 4: 3, 5: 10})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 71-80)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=81) &(df['AGE_YRS']<=90)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({2: 2, 1: 1})
# Counter({1: 1, 2: 2})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 81-90)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=91) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({3: 1})
# Counter({3: 1})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,Moderna,Male (Age 91-100)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=20) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 132, 3: 63, 2: 55, 1: 47, 4: 46})
# Counter({1: 47, 2: 55, 3: 63, 4: 46, 5: 132})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Pie Chart based on Asthma,using PFIZER\BIONTECH on Male,Age(20-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=20) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 520, 2: 205, 3: 204, 1: 193, 4: 176})
# Counter({1: 193, 2: 205, 3: 204, 4: 176, 5: 520})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Pie Chart based on Asthma,using PFIZER\BIONTECH on Female,Age(20-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 64, 3: 28, 2: 27, 1: 23, 4: 22})
# Counter({1: 23, 2: 27, 3: 28, 4: 22, 5: 64})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 52, 1: 18, 2: 15, 3: 15, 4: 10})
# Counter({1: 18, 2: 15, 3: 15, 4: 10, 5: 52})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 22, 2: 16, 1: 9, 4: 9, 3: 8})
# Counter({1: 9, 2: 16, 3: 8, 4: 9, 5: 22})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({2: 18, 5: 17, 3: 13, 4: 13, 1: 4})
# Counter({1: 4, 2: 18, 3: 13, 4: 13, 5: 17})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 5, 1: 4, 2: 3, 3: 2, 4: 2})
# Counter({1: 4, 2: 3, 3: 2, 4: 2, 5: 5})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 71-80)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=81) &(df['AGE_YRS']<=90)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({2: 1})
# Counter({2: 1})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,PFIZER\BIONTECH,Male (Age 81-90)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 21, 3: 12, 4: 11, 2: 8, 1: 6})
# Counter({1: 6, 2: 8, 3: 12, 4: 11, 5: 21})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 21-30)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 21, 4: 11, 1: 7, 3: 6, 2: 4})
# Counter({1: 7, 2: 4, 3: 6, 4: 11, 5: 21})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 31-40)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 24, 2: 8, 3: 7, 4: 4, 1: 4})
# Counter({1: 4, 2: 8, 3: 7, 4: 4, 5: 24})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 41-50)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({5: 14, 4: 11, 1: 4, 2: 3, 3: 3})
# Counter({1: 4, 2: 3, 3: 3, 4: 11, 5: 14})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 51-60)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({3: 2, 2: 1})
# Counter({2: 1, 3: 2})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 61-70)')
plt.show()

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['Total']))
dict=Counter(fdata['Total'])
dict
# Out:
# Counter({3: 1})
# Counter({3: 1})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Asthma,JANSSEN,Male (Age 71-80)')
plt.show()

# %% [markdown]
# **Asthma, Moderna**

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="F") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total VAX_MANU  AGE_YRS SEX HISTORY
# 158         4  MODERNA     48.0   F  Asthma
# 208         4  MODERNA     30.0   F  Asthma
# 347         4  MODERNA     56.0   F  Asthma
# 472         5  MODERNA     60.0   F  Asthma
# 473         3  MODERNA     60.0   F  Asthma
# ...       ...      ...      ...  ..     ...
# 887423      3  MODERNA     40.0   F  Asthma
# 888287      4  MODERNA     38.0   F  Asthma
# 888608      2  MODERNA     27.0   F  Asthma
# 889297      5  MODERNA     28.0   F  Asthma
# 889298      4  MODERNA     28.0   F  Asthma
#
# [3205 rows x 5 columns]

# %%
mdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="MODERNA")&(df.SEX=="M") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
mdata
# Out:
#         Total VAX_MANU  AGE_YRS SEX HISTORY
# 388         5  MODERNA     40.0   M  Asthma
# 389         5  MODERNA     40.0   M  Asthma
# 390         1  MODERNA     40.0   M  Asthma
# 601         3  MODERNA     27.0   M  Asthma
# 1166        5  MODERNA     20.0   M  Asthma
# ...       ...      ...      ...  ..     ...
# 886870      2  MODERNA     21.0   M  Asthma
# 889735      5  MODERNA     47.0   M  Asthma
# 889736      2  MODERNA     47.0   M  Asthma
# 890426      3  MODERNA     30.0   M  Asthma
# 890427      3  MODERNA     30.0   M  Asthma
#
# [622 rows x 5 columns]

# %%
sns.lineplot(x='AGE_YRS',y='Total', data=fdata)
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
plt.ylabel('Different Types of symptoms')
# Setting title of the plot
plt.title("Lineplot based on Asthma,using Moderna on Female,Age(10-100)");

# %%
sns.countplot(x="Total",data=fdata,
palette="rainbow")
plt.xlabel('Different Types of Symptoms')
plt.title("Countplot based on 'Different Types of Symptoms' on Female");

# %%
fdata=df[(df.HISTORY=="Asthma")&(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total         VAX_MANU  AGE_YRS SEX HISTORY
# 56          3  PFIZER\BIONTECH     47.0   F  Asthma
# 158         4          MODERNA     48.0   F  Asthma
# 208         4          MODERNA     30.0   F  Asthma
# 347         4          MODERNA     56.0   F  Asthma
# 388         5          MODERNA     40.0   M  Asthma
# ...       ...              ...      ...  ..     ...
# 889732      3  PFIZER\BIONTECH     63.0   M  Asthma
# 889735      5          MODERNA     47.0   M  Asthma
# 889736      2          MODERNA     47.0   M  Asthma
# 890426      3          MODERNA     30.0   M  Asthma
# 890427      3          MODERNA     30.0   M  Asthma
#
# [8215 rows x 5 columns]

# %%
sns.countplot(x="Total",data=fdata,
palette="rainbow")
plt.xlabel('Different Types of Symptoms')
plt.title("Countplot based on 'Different Types of Symptoms'");

# %%
# Changing color palette
sns.set_palette('winter')
plt.subplot(211)
sns.lineplot(x='AGE_YRS',y='Total',data=fdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
plt.ylabel('Different Types of Symptoms')
plt.title("Lineplot Female vs Male based on 'Age'");

# Changing color palette
sns.set_palette('prism')
plt.subplot(212)
sns.lineplot(x='AGE_YRS',y='Total',data=mdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
# Out:
# (1.0, 5.0)

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="F") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total         VAX_MANU  AGE_YRS SEX HISTORY
# 56          3  PFIZER\BIONTECH     47.0   F  Asthma
# 891         5  PFIZER\BIONTECH     42.0   F  Asthma
# 892         5  PFIZER\BIONTECH     42.0   F  Asthma
# 893         2  PFIZER\BIONTECH     42.0   F  Asthma
# 1200        4  PFIZER\BIONTECH     37.0   F  Asthma
# ...       ...              ...      ...  ..     ...
# 888991      5  PFIZER\BIONTECH     33.0   F  Asthma
# 888992      5  PFIZER\BIONTECH     33.0   F  Asthma
# 888993      1  PFIZER\BIONTECH     33.0   F  Asthma
# 889024      5  PFIZER\BIONTECH     67.0   F  Asthma
# 889025      2  PFIZER\BIONTECH     67.0   F  Asthma
#
# [2699 rows x 5 columns]

# %%
mdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="PFIZER\BIONTECH")&(df.SEX=="M") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
mdata
# Out:
#         Total         VAX_MANU  AGE_YRS SEX HISTORY
# 1287        3  PFIZER\BIONTECH     57.0   M  Asthma
# 3176        5  PFIZER\BIONTECH     28.0   M  Asthma
# 3177        2  PFIZER\BIONTECH     28.0   M  Asthma
# 6547        5  PFIZER\BIONTECH     33.0   M  Asthma
# 6548        1  PFIZER\BIONTECH     33.0   M  Asthma
# ...       ...              ...      ...  ..     ...
# 884338      1  PFIZER\BIONTECH     15.0   M  Asthma
# 884452      5  PFIZER\BIONTECH     29.0   M  Asthma
# 884453      5  PFIZER\BIONTECH     29.0   M  Asthma
# 889021      2  PFIZER\BIONTECH     19.0   M  Asthma
# 889732      3  PFIZER\BIONTECH     63.0   M  Asthma
#
# [791 rows x 5 columns]

# %%
# Changing color palette
sns.set_palette('winter')
plt.subplot(211)
sns.lineplot(x='AGE_YRS',y='Total',data=fdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
plt.ylabel('Different Types of Symptoms')
plt.title("Lineplot Female vs Male based on 'Age'");

# Changing color palette
sns.set_palette('prism')
plt.subplot(212)
sns.lineplot(x='AGE_YRS',y='Total',data=mdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
# Out:
# (1.0, 5.0)

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="F") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total VAX_MANU  AGE_YRS SEX HISTORY
# 175342      3  JANSSEN     19.0   F  Asthma
# 176219      5  JANSSEN     44.0   F  Asthma
# 176220      3  JANSSEN     44.0   F  Asthma
# 176320      5  JANSSEN     34.0   F  Asthma
# 176321      2  JANSSEN     34.0   F  Asthma
# ...       ...      ...      ...  ..     ...
# 858355      4  JANSSEN     41.0   F  Asthma
# 870804      5  JANSSEN     57.0   F  Asthma
# 870805      4  JANSSEN     57.0   F  Asthma
# 873773      5  JANSSEN     43.0   F  Asthma
# 873774      5  JANSSEN     43.0   F  Asthma
#
# [640 rows x 5 columns]

# %%
mdata=df[(df.HISTORY=="Asthma")&(df.VAX_MANU=="JANSSEN")&(df.SEX=="M") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
mdata
# Out:
#         Total VAX_MANU  AGE_YRS SEX HISTORY
# 176453      4  JANSSEN     53.0   M  Asthma
# 177099      5  JANSSEN     28.0   M  Asthma
# 178928      5  JANSSEN     54.0   M  Asthma
# 178929      5  JANSSEN     54.0   M  Asthma
# 178930      4  JANSSEN     54.0   M  Asthma
# ...       ...      ...      ...  ..     ...
# 885211      5  JANSSEN     41.0   M  Asthma
# 885212      5  JANSSEN     41.0   M  Asthma
# 885213      4  JANSSEN     41.0   M  Asthma
# 889046      5  JANSSEN     49.0   M  Asthma
# 889047      1  JANSSEN     49.0   M  Asthma
#
# [225 rows x 5 columns]

# %%
# Changing color palette
sns.set_palette('winter')
plt.subplot(211)
sns.lineplot(x='AGE_YRS',y='Total',data=fdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
plt.ylabel('Different Types of Symptoms')
plt.title("Lineplot Female vs Male based on 'Age'");

# Changing color palette
sns.set_palette('prism')
plt.subplot(212)
sns.lineplot(x='AGE_YRS',y='Total',data=mdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
# Out:
# (1.0, 5.0)

# %%
fdata=df[(df.HISTORY=="Asthma")&(df.SEX=="F") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
fdata
# Out:
#         Total         VAX_MANU  AGE_YRS SEX HISTORY
# 56          3  PFIZER\BIONTECH     47.0   F  Asthma
# 158         4          MODERNA     48.0   F  Asthma
# 208         4          MODERNA     30.0   F  Asthma
# 347         4          MODERNA     56.0   F  Asthma
# 472         5          MODERNA     60.0   F  Asthma
# ...       ...              ...      ...  ..     ...
# 888993      1  PFIZER\BIONTECH     33.0   F  Asthma
# 889024      5  PFIZER\BIONTECH     67.0   F  Asthma
# 889025      2  PFIZER\BIONTECH     67.0   F  Asthma
# 889297      5          MODERNA     28.0   F  Asthma
# 889298      4          MODERNA     28.0   F  Asthma
#
# [6556 rows x 5 columns]

# %%
mdata=df[(df.HISTORY=="Asthma")&(df.SEX=="M") &(df['AGE_YRS']>=10) &(df['AGE_YRS']<=100)][["Total","VAX_MANU","AGE_YRS","SEX","HISTORY"]]
mdata
# Out:
#         Total         VAX_MANU  AGE_YRS SEX HISTORY
# 388         5          MODERNA     40.0   M  Asthma
# 389         5          MODERNA     40.0   M  Asthma
# 390         1          MODERNA     40.0   M  Asthma
# 601         3          MODERNA     27.0   M  Asthma
# 1166        5          MODERNA     20.0   M  Asthma
# ...       ...              ...      ...  ..     ...
# 889732      3  PFIZER\BIONTECH     63.0   M  Asthma
# 889735      5          MODERNA     47.0   M  Asthma
# 889736      2          MODERNA     47.0   M  Asthma
# 890426      3          MODERNA     30.0   M  Asthma
# 890427      3          MODERNA     30.0   M  Asthma
#
# [1639 rows x 5 columns]

# %% [markdown]
# **All vaccine type**

# %%
# Changing color palette
sns.set_palette('winter')
plt.subplot(211)
sns.lineplot(x='AGE_YRS',y='Total',data=fdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
plt.ylabel('Different Types of Symptoms')
plt.title("Lineplot Female vs Male based on 'Age'");

# Changing color palette
sns.set_palette('prism')
plt.subplot(212)
sns.lineplot(x='AGE_YRS',y='Total',data=mdata);
plt.xlim(10,100)# Setting xlim
plt.ylim(1,5)# Setting ylim
# Out:
# (1.0, 5.0)
