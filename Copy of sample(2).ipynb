# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/dataset/main.xlsx")
df.head()
# Out:
#                   SYMPTOM1    1    2  ...   RECVDATE  AGE_YRS SEX
# 0                Dysphagia  1.0  1.0  ... 2021-01-01     33.0   F
# 1                  Anxiety  1.0  1.0  ... 2021-01-01     73.0   F
# 2         Chest discomfort  1.0  1.0  ... 2021-01-01     23.0   F
# 3                Dizziness  1.0  1.0  ... 2021-01-01     58.0   F
# 4  Injection site erythema  1.0  1.0  ... 2021-01-01     47.0   F
#
# [5 rows x 17 columns]

# %%
import pandas as pd
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

df = pd.read_excel("/content/drive/MyDrive/dataset/main.xlsx")

sums = df.groupby(df["VAX_MANU"])["Sum"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()
